# %% [markdown]
# <a href="https://colab.research.google.com/github/kewingchang/CryptoMamba/blob/Quantiles/training_many_from_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title System requirements
# 1. Training using stable mamba_ssm and causal_conv1d
# 2. torch == 2.9.0+cu126(cxx11abiTRUE)
# 3. python 3.12.12
# 4. mamba_ssm-2.2.5, causal_conv1d-1.5.2

# %%
# @title Cloning
# !git clone -b Quantiles https://github.com/kewingchang/CryptoMamba
# %cd CryptoMamba/

# %%
# @title Mount google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# @title Installing requirements
# !pip uninstall tensorflow -y
# !pip uninstall tensorflow-decision-forests dopamine-rl -y
# !pip uninstall tf_keras tf-slim -y
# !pip uninstall tensorflow-datasets tensorflow-hub tensorflow-metadata tensorflow-probability tensorflow-text -y

# !pip install -q ninja

# 拷贝whl from drive
# causal_conv1d-1.5.3.post1, mamba_ssm-2.2.6.post3
# !cp /content/drive/MyDrive/my_libs/T4_python3.12_torch2.9.0+cu126_cxx11abiTRUE/causal_conv1d-1.5.3.post1-cp312-cp312-linux_x86_64.whl /tmp/
# !cp /content/drive/MyDrive/my_libs/T4_python3.12_torch2.9.0+cu126_cxx11abiTRUE/mamba_ssm-2.2.6.post3-cp312-cp312-linux_x86_64.whl /tmp/

# 安装 wheel 文件
# !pip install /tmp/causal_conv1d-1.5.3.post1-cp312-cp312-linux_x86_64.whl /tmp/mamba_ssm-2.2.6.post3-cp312-cp312-linux_x86_64.whl -v --no-build-isolation

# install others
# !pip install -r requirements.txt

# %%
# @title Train many
# !python scripts/train_many_from_json.py --filename features.json

# %%
# @title Extract from drive
# !python scripts/extract_mase_qlow.py --data_dir /content/drive/MyDrive/training/20251228
