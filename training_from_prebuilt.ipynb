# %%
# @title Cloning
# !git clone -b Training https://github.com/kewingchang/CryptoMamba
# %cd CryptoMamba/
# Out:
# Cloning into 'CryptoMamba'...
# remote: Enumerating objects: 1584, done.
# remote: Counting objects: 100% (415/415), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 1584 (delta 365), reused 239 (delta 239), pack-reused 1169 (from 2)
# Receiving objects: 100% (1584/1584), 15.37 MiB | 16.11 MiB/s, done.
# Resolving deltas: 100% (823/823), done.
# /content/CryptoMamba

# %%
# @title Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title Uninstall tensorflow
# !pip uninstall tensorflow -y
# Out:
# Found existing installation: tensorflow 2.19.0
# Uninstalling tensorflow-2.19.0:
#   Successfully uninstalled tensorflow-2.19.0

# %%
# @title Copy causal_conv1d, mamba-ssm
# !cp -r /content/drive/MyDrive/my_libs/causal_conv1d /usr/local/lib/python3.12/dist-packages/
# !cp /content/drive/MyDrive/my_libs/causal_conv1d_cuda.cpython-312-x86_64-linux-gnu.so /usr/local/lib/python3.12/dist-packages/
# !cp -r /content/drive/MyDrive/my_libs/mamba_ssm-2.2.6.post3.dist-info /usr/local/lib/python3.12/dist-packages/
# !cp -r /content/drive/MyDrive/my_libs/mamba_ssm /usr/local/lib/python3.12/dist-packages/
# !cp /content/drive/MyDrive/my_libs/selective_scan_cuda.cpython-312-x86_64-linux-gnu.so /usr/local/lib/python3.12/dist-packages/
# !cp -r /content/drive/MyDrive/my_libs/causal_conv1d-1.5.3.post1.dist-info /usr/local/lib/python3.12/dist-packages/

# %%
# @title Installing requirements
# !pip install -q ninja
# !pip install -q torch
# !pip install -q torchvision
# !pip install -q torchaudio
# !pip install -q setuptools
# !pip install -q pyaml
# !pip install -q lightning
# !pip install -q matplotlib
# !pip install -q seaborn
# !pip install -q pandas
# !pip install -q einops
# !pip install -q tensorboard
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.5/828.5 kB 65.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 59.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 73.0 MB/s eta 0:00:00

# %%
# @title Training
# !python scripts/training-reproducibility.py --config cmamba_v --save_checkpoints
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 33.58it/s]
# Epoch 169: 100% 46/46 [00:04<00:00, 11.22it/s, v_num=0, train/rmse=729.0, train/mape=2.640, val/rmse=657.0, val/mape=0.357]Epoch 169, global step 7820: 'val/rmse' was not in top 1
# Epoch 170: 100% 46/46 [00:04<00:00,  9.59it/s, v_num=0, train/rmse=1.28e+3, train/mape=4.870, val/rmse=657.0, val/mape=0.357]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 33.20it/s]
# Epoch 170: 100% 46/46 [00:05<00:00,  8.57it/s, v_num=0, train/rmse=1.28e+3, train/mape=4.870, val/rmse=584.0, val/mape=0.311]Epoch 170, global step 7866: 'val/rmse' was not in top 1
# Epoch 171: 100% 46/46 [00:03<00:00, 13.00it/s, v_num=0, train/rmse=1.29e+3, train/mape=3.770, val/rmse=584.0, val/mape=0.311]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.84it/s]
# Epoch 171: 100% 46/46 [00:04<00:00, 11.21it/s, v_num=0, train/rmse=1.29e+3, train/mape=3.770, val/rmse=384.0, val/mape=0.189]Epoch 171, global step 7912: 'val/rmse' was not in top 1
# Epoch 172: 100% 46/46 [00:03<00:00, 13.03it/s, v_num=0, train/rmse=1.37e+3, train/mape=3.020, val/rmse=384.0, val/mape=0.189]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.25it/s]
# Epoch 172: 100% 46/46 [00:04<00:00, 11.20it/s, v_num=0, train/rmse=1.37e+3, train/mape=3.020, val/rmse=602.0, val/mape=0.321]Epoch 172, global step 7958: 'val/rmse' was not in top 1
# Epoch 173: 100% 46/46 [00:04<00:00,  9.88it/s, v_num=0, train/rmse=1.5e+3, train/mape=1.230, val/rmse=602.0, val/mape=0.321]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 33.92it/s]
# Epoch 173: 100% 46/46 [00:05<00:00,  8.80it/s, v_num=0, train/rmse=1.5e+3, train/mape=1.230, val/rmse=507.0, val/mape=0.256]Epoch 173, global step 8004: 'val/rmse' was not in top 1
# Epoch 174: 100% 46/46 [00:03<00:00, 13.04it/s, v_num=0, train/rmse=999.0, train/mape=3.350, val/rmse=507.0, val/mape=0.256]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.41it/s]
# Epoch 174: 100% 46/46 [00:04<00:00, 11.23it/s, v_num=0, train/rmse=999.0, train/mape=3.350, val/rmse=558.0, val/mape=0.291]Epoch 174, global step 8050: 'val/rmse' was not in top 1
# Epoch 175: 100% 46/46 [00:03<00:00, 13.08it/s, v_num=0, train/rmse=2.14e+3, train/mape=1.040, val/rmse=558.0, val/mape=0.291]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 28.12it/s]
# Epoch 175: 100% 46/46 [00:04<00:00, 11.06it/s, v_num=0, train/rmse=2.14e+3, train/mape=1.040, val/rmse=635.0, val/mape=0.343]Epoch 175, global step 8096: 'val/rmse' was not in top 1
# Epoch 176: 100% 46/46 [00:04<00:00,  9.81it/s, v_num=0, train/rmse=1.49e+3, train/mape=2.570, val/rmse=635.0, val/mape=0.343]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.24it/s]
# Epoch 176: 100% 46/46 [00:05<00:00,  8.75it/s, v_num=0, train/rmse=1.49e+3, train/mape=2.570, val/rmse=576.0, val/mape=0.304]Epoch 176, global step 8142: 'val/rmse' was not in top 1
# Epoch 177: 100% 46/46 [00:03<00:00, 13.00it/s, v_num=0, train/rmse=1.16e+3, train/mape=3.590, val/rmse=576.0, val/mape=0.304]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.65it/s]
# Epoch 177: 100% 46/46 [00:04<00:00, 11.18it/s, v_num=0, train/rmse=1.16e+3, train/mape=3.590, val/rmse=457.0, val/mape=0.224]Epoch 177, global step 8188: 'val/rmse' was not in top 1
# Epoch 178: 100% 46/46 [00:03<00:00, 13.03it/s, v_num=0, train/rmse=1.02e+3, train/mape=3.940, val/rmse=457.0, val/mape=0.224]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 23.94it/s]
# Epoch 178: 100% 46/46 [00:04<00:00, 10.71it/s, v_num=0, train/rmse=1.02e+3, train/mape=3.940, val/rmse=558.0, val/mape=0.291]Epoch 178, global step 8234: 'val/rmse' was not in top 1
# Epoch 179: 100% 46/46 [00:04<00:00, 10.32it/s, v_num=0, train/rmse=1.14e+3, train/mape=3.840, val/rmse=558.0, val/mape=0.291]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 29.87it/s]
# Epoch 179: 100% 46/46 [00:05<00:00,  9.16it/s, v_num=0, train/rmse=1.14e+3, train/mape=3.840, val/rmse=527.0, val/mape=0.270]Epoch 179, global step 8280: 'val/rmse' was not in top 1
# Epoch 180: 100% 46/46 [00:03<00:00, 13.05it/s, v_num=0, train/rmse=1.32e+3, train/mape=3.900, val/rmse=527.0, val/mape=0.270]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.15it/s]
# Epoch 180: 100% 46/46 [00:04<00:00, 11.22it/s, v_num=0, train/rmse=1.32e+3, train/mape=3.900, val/rmse=487.0, val/mape=0.242]Epoch 180, global step 8326: 'val/rmse' was not in top 1
# Epoch 181: 100% 46/46 [00:03<00:00, 12.67it/s, v_num=0, train/rmse=1.49e+3, train/mape=2.040, val/rmse=487.0, val/mape=0.242]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 21.48it/s]
# Epoch 181: 100% 46/46 [00:04<00:00, 10.32it/s, v_num=0, train/rmse=1.49e+3, train/mape=2.040, val/rmse=505.0, val/mape=0.253]Epoch 181, global step 8372: 'val/rmse' was not in top 1
# Epoch 182: 100% 46/46 [00:04<00:00, 10.73it/s, v_num=0, train/rmse=1.22e+3, train/mape=3.960, val/rmse=505.0, val/mape=0.253]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.60it/s]
# Epoch 182: 100% 46/46 [00:04<00:00,  9.48it/s, v_num=0, train/rmse=1.22e+3, train/mape=3.960, val/rmse=285.0, val/mape=0.154]Epoch 182, global step 8418: 'val/rmse' was not in top 1
# Epoch 183: 100% 46/46 [00:03<00:00, 12.67it/s, v_num=0, train/rmse=1.7e+3, train/mape=4.190, val/rmse=285.0, val/mape=0.154]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.29it/s]
# Epoch 183: 100% 46/46 [00:04<00:00, 10.97it/s, v_num=0, train/rmse=1.7e+3, train/mape=4.190, val/rmse=266.0, val/mape=0.149]Epoch 183, global step 8464: 'val/rmse' was not in top 1
# Epoch 184: 100% 46/46 [00:03<00:00, 11.97it/s, v_num=0, train/rmse=1.87e+3, train/mape=3.360, val/rmse=266.0, val/mape=0.149]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 22.61it/s]
# Epoch 184: 100% 46/46 [00:04<00:00,  9.83it/s, v_num=0, train/rmse=1.87e+3, train/mape=3.360, val/rmse=343.0, val/mape=0.188]Epoch 184, global step 8510: 'val/rmse' was not in top 1
# Epoch 185: 100% 46/46 [00:04<00:00, 11.16it/s, v_num=0, train/rmse=1.48e+3, train/mape=5.430, val/rmse=343.0, val/mape=0.188]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.54it/s]
# Epoch 185: 100% 46/46 [00:04<00:00,  9.78it/s, v_num=0, train/rmse=1.48e+3, train/mape=5.430, val/rmse=365.0, val/mape=0.183]Epoch 185, global step 8556: 'val/rmse' was not in top 1
# Epoch 186: 100% 46/46 [00:03<00:00, 13.01it/s, v_num=0, train/rmse=921.0, train/mape=4.810, val/rmse=365.0, val/mape=0.183]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.97it/s]
# Epoch 186: 100% 46/46 [00:04<00:00, 11.20it/s, v_num=0, train/rmse=921.0, train/mape=4.810, val/rmse=834.0, val/mape=0.477]Epoch 186, global step 8602: 'val/rmse' was not in top 1
# Epoch 187: 100% 46/46 [00:03<00:00, 11.53it/s, v_num=0, train/rmse=967.0, train/mape=4.400, val/rmse=834.0, val/mape=0.477]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 22.07it/s]
# Epoch 187: 100% 46/46 [00:04<00:00,  9.51it/s, v_num=0, train/rmse=967.0, train/mape=4.400, val/rmse=532.0, val/mape=0.272]Epoch 187, global step 8648: 'val/rmse' was not in top 1
# Epoch 188: 100% 46/46 [00:03<00:00, 11.76it/s, v_num=0, train/rmse=1.05e+3, train/mape=4.740, val/rmse=532.0, val/mape=0.272]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.82it/s]
# Epoch 188: 100% 46/46 [00:04<00:00, 10.23it/s, v_num=0, train/rmse=1.05e+3, train/mape=4.740, val/rmse=811.0, val/mape=0.461]Epoch 188, global step 8694: 'val/rmse' was not in top 1
# Epoch 189: 100% 46/46 [00:03<00:00, 12.97it/s, v_num=0, train/rmse=1.28e+3, train/mape=6.450, val/rmse=811.0, val/mape=0.461]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.75it/s]
# Epoch 189: 100% 46/46 [00:04<00:00, 11.14it/s, v_num=0, train/rmse=1.28e+3, train/mape=6.450, val/rmse=525.0, val/mape=0.267]Epoch 189, global step 8740: 'val/rmse' was not in top 1
# Epoch 190: 100% 46/46 [00:04<00:00, 10.73it/s, v_num=0, train/rmse=1.41e+3, train/mape=4.700, val/rmse=525.0, val/mape=0.267]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 21.00it/s]
# Epoch 190: 100% 46/46 [00:05<00:00,  8.88it/s, v_num=0, train/rmse=1.41e+3, train/mape=4.700, val/rmse=526.0, val/mape=0.269]Epoch 190, global step 8786: 'val/rmse' was not in top 1
# Epoch 191: 100% 46/46 [00:03<00:00, 12.53it/s, v_num=0, train/rmse=1.93e+3, train/mape=0.809, val/rmse=526.0, val/mape=0.269]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.15it/s]
# Epoch 191: 100% 46/46 [00:04<00:00, 10.88it/s, v_num=0, train/rmse=1.93e+3, train/mape=0.809, val/rmse=843.0, val/mape=0.480]Epoch 191, global step 8832: 'val/rmse' was not in top 1
# Epoch 192: 100% 46/46 [00:03<00:00, 12.96it/s, v_num=0, train/rmse=1.14e+4, train/mape=35.40, val/rmse=843.0, val/mape=0.480]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.82it/s]
# Epoch 192: 100% 46/46 [00:04<00:00, 11.18it/s, v_num=0, train/rmse=1.14e+4, train/mape=35.40, val/rmse=3.84e+3, val/mape=2.450]Epoch 192, global step 8878: 'val/rmse' was not in top 1
# Epoch 193: 100% 46/46 [00:04<00:00, 10.75it/s, v_num=0, train/rmse=1.31e+3, train/mape=1.770, val/rmse=3.84e+3, val/mape=2.450]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 22.31it/s]
# Epoch 193: 100% 46/46 [00:05<00:00,  8.98it/s, v_num=0, train/rmse=1.31e+3, train/mape=1.770, val/rmse=526.0, val/mape=0.273]Epoch 193, global step 8924: 'val/rmse' was not in top 1
# Epoch 194: 100% 46/46 [00:03<00:00, 12.81it/s, v_num=0, train/rmse=1.26e+3, train/mape=1.270, val/rmse=526.0, val/mape=0.273]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.72it/s]
# Epoch 194: 100% 46/46 [00:04<00:00, 11.10it/s, v_num=0, train/rmse=1.26e+3, train/mape=1.270, val/rmse=310.0, val/mape=0.165]Epoch 194, global step 8970: 'val/rmse' was not in top 1
# Epoch 195: 100% 46/46 [00:03<00:00, 13.02it/s, v_num=0, train/rmse=1.92e+3, train/mape=2.470, val/rmse=310.0, val/mape=0.165]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.80it/s]
# Epoch 195: 100% 46/46 [00:04<00:00, 11.25it/s, v_num=0, train/rmse=1.92e+3, train/mape=2.470, val/rmse=350.0, val/mape=0.180]Epoch 195, global step 9016: 'val/rmse' was not in top 1
# Epoch 196: 100% 46/46 [00:04<00:00, 10.60it/s, v_num=0, train/rmse=1.13e+3, train/mape=2.730, val/rmse=350.0, val/mape=0.180]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 17.78it/s]
# Epoch 196: 100% 46/46 [00:05<00:00,  8.62it/s, v_num=0, train/rmse=1.13e+3, train/mape=2.730, val/rmse=660.0, val/mape=0.364]Epoch 196, global step 9062: 'val/rmse' was not in top 1
# Epoch 197: 100% 46/46 [00:03<00:00, 12.81it/s, v_num=0, train/rmse=1.22e+3, train/mape=0.992, val/rmse=660.0, val/mape=0.364]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.14it/s]
# Epoch 197: 100% 46/46 [00:04<00:00, 11.02it/s, v_num=0, train/rmse=1.22e+3, train/mape=0.992, val/rmse=1.05e+3, val/mape=0.617]Epoch 197, global step 9108: 'val/rmse' was not in top 1
# Epoch 198: 100% 46/46 [00:03<00:00, 13.17it/s, v_num=0, train/rmse=1.66e+3, train/mape=1.330, val/rmse=1.05e+3, val/mape=0.617]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 33.69it/s]
# Epoch 198: 100% 46/46 [00:04<00:00, 11.32it/s, v_num=0, train/rmse=1.66e+3, train/mape=1.330, val/rmse=569.0, val/mape=0.303]Epoch 198, global step 9154: 'val/rmse' was not in top 1
# Epoch 199: 100% 46/46 [00:04<00:00, 10.67it/s, v_num=0, train/rmse=1.49e+3, train/mape=5.550, val/rmse=569.0, val/mape=0.303]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 21.19it/s]
# Epoch 199: 100% 46/46 [00:05<00:00,  8.89it/s, v_num=0, train/rmse=1.49e+3, train/mape=5.550, val/rmse=347.0, val/mape=0.192]Epoch 199, global step 9200: 'val/rmse' was not in top 1
# Epoch 200: 100% 46/46 [00:03<00:00, 12.93it/s, v_num=0, train/rmse=1.52e+3, train/mape=2.690, val/rmse=347.0, val/mape=0.192]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 33.22it/s]
# Epoch 200: 100% 46/46 [00:04<00:00, 11.14it/s, v_num=0, train/rmse=1.52e+3, train/mape=2.690, val/rmse=508.0, val/mape=0.260]Epoch 200, global step 9246: 'val/rmse' was not in top 1
# Epoch 201: 100% 46/46 [00:03<00:00, 12.99it/s, v_num=0, train/rmse=1.52e+3, train/mape=4.390, val/rmse=508.0, val/mape=0.260]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 33.59it/s]
# Epoch 201: 100% 46/46 [00:04<00:00, 11.23it/s, v_num=0, train/rmse=1.52e+3, train/mape=4.390, val/rmse=490.0, val/mape=0.248]Epoch 201, global step 9292: 'val/rmse' was not in top 1
# Epoch 202: 100% 46/46 [00:04<00:00, 10.17it/s, v_num=0, train/rmse=2.11e+3, train/mape=2.590, val/rmse=490.0, val/mape=0.248]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 25.39it/s]
# Epoch 202: 100% 46/46 [00:05<00:00,  8.75it/s, v_num=0, train/rmse=2.11e+3, train/mape=2.590, val/rmse=603.0, val/mape=0.327]Epoch 202, global step 9338: 'val/rmse' was not in top 1
# Epoch 203: 100% 46/46 [00:03<00:00, 12.63it/s, v_num=0, train/rmse=1.4e+3, train/mape=3.630, val/rmse=603.0, val/mape=0.327]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 33.63it/s]
# Epoch 203: 100% 46/46 [00:04<00:00, 10.93it/s, v_num=0, train/rmse=1.4e+3, train/mape=3.630, val/rmse=301.0, val/mape=0.156]Epoch 203, global step 9384: 'val/rmse' was not in top 1
# Epoch 204: 100% 46/46 [00:03<00:00, 12.88it/s, v_num=0, train/rmse=1.16e+3, train/mape=3.360, val/rmse=301.0, val/mape=0.156]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.34it/s]
# Epoch 204: 100% 46/46 [00:04<00:00, 11.09it/s, v_num=0, train/rmse=1.16e+3, train/mape=3.360, val/rmse=373.0, val/mape=0.183]Epoch 204, global step 9430: 'val/rmse' was not in top 1
# Epoch 205: 100% 46/46 [00:04<00:00,  9.89it/s, v_num=0, train/rmse=1.25e+3, train/mape=2.520, val/rmse=373.0, val/mape=0.183]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.89it/s]
# Epoch 205: 100% 46/46 [00:05<00:00,  8.79it/s, v_num=0, train/rmse=1.25e+3, train/mape=2.520, val/rmse=469.0, val/mape=0.285]Epoch 205, global step 9476: 'val/rmse' was not in top 1
# Epoch 206: 100% 46/46 [00:03<00:00, 13.19it/s, v_num=0, train/rmse=929.0, train/mape=3.250, val/rmse=469.0, val/mape=0.285]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.97it/s]
# Epoch 206: 100% 46/46 [00:04<00:00, 11.33it/s, v_num=0, train/rmse=929.0, train/mape=3.250, val/rmse=375.0, val/mape=0.183]Epoch 206, global step 9522: 'val/rmse' was not in top 1
# Epoch 207: 100% 46/46 [00:03<00:00, 12.93it/s, v_num=0, train/rmse=1.18e+3, train/mape=3.530, val/rmse=375.0, val/mape=0.183]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.32it/s]
# Epoch 207: 100% 46/46 [00:04<00:00, 11.11it/s, v_num=0, train/rmse=1.18e+3, train/mape=3.530, val/rmse=668.0, val/mape=0.422]Epoch 207, global step 9568: 'val/rmse' was not in top 1
# Epoch 208: 100% 46/46 [00:04<00:00,  9.84it/s, v_num=0, train/rmse=1.28e+3, train/mape=6.860, val/rmse=668.0, val/mape=0.422]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.20it/s]
# Epoch 208: 100% 46/46 [00:05<00:00,  8.75it/s, v_num=0, train/rmse=1.28e+3, train/mape=6.860, val/rmse=323.0, val/mape=0.163]Epoch 208, global step 9614: 'val/rmse' was not in top 1
# Epoch 209: 100% 46/46 [00:03<00:00, 12.97it/s, v_num=0, train/rmse=851.0, train/mape=4.040, val/rmse=323.0, val/mape=0.163]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.72it/s]
# Epoch 209: 100% 46/46 [00:04<00:00, 11.19it/s, v_num=0, train/rmse=851.0, train/mape=4.040, val/rmse=889.0, val/mape=0.519]Epoch 209, global step 9660: 'val/rmse' was not in top 1
# Epoch 210: 100% 46/46 [00:03<00:00, 12.52it/s, v_num=0, train/rmse=1.47e+3, train/mape=2.340, val/rmse=889.0, val/mape=0.519]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.39it/s]
# Epoch 210: 100% 46/46 [00:04<00:00, 10.87it/s, v_num=0, train/rmse=1.47e+3, train/mape=2.340, val/rmse=730.0, val/mape=0.413]Epoch 210, global step 9706: 'val/rmse' was not in top 1
# Epoch 211: 100% 46/46 [00:04<00:00,  9.87it/s, v_num=0, train/rmse=1.74e+3, train/mape=3.650, val/rmse=730.0, val/mape=0.413]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 29.96it/s]
# Epoch 211: 100% 46/46 [00:05<00:00,  8.78it/s, v_num=0, train/rmse=1.74e+3, train/mape=3.650, val/rmse=811.0, val/mape=0.468]Epoch 211, global step 9752: 'val/rmse' was not in top 1
# Epoch 212: 100% 46/46 [00:03<00:00, 12.89it/s, v_num=0, train/rmse=1.29e+3, train/mape=1.820, val/rmse=811.0, val/mape=0.468]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.85it/s]
# Epoch 212: 100% 46/46 [00:04<00:00, 11.11it/s, v_num=0, train/rmse=1.29e+3, train/mape=1.820, val/rmse=346.0, val/mape=0.198]Epoch 212, global step 9798: 'val/rmse' was not in top 1
# Epoch 213: 100% 46/46 [00:03<00:00, 12.82it/s, v_num=0, train/rmse=585.0, train/mape=1.770, val/rmse=346.0, val/mape=0.198]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.58it/s]
# Epoch 213: 100% 46/46 [00:04<00:00, 11.04it/s, v_num=0, train/rmse=585.0, train/mape=1.770, val/rmse=2.13e+3, val/mape=1.310]Epoch 213, global step 9844: 'val/rmse' was not in top 1
# Epoch 214: 100% 46/46 [00:04<00:00,  9.64it/s, v_num=0, train/rmse=1.06e+3, train/mape=1.690, val/rmse=2.13e+3, val/mape=1.310]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.20it/s]
# Epoch 214: 100% 46/46 [00:05<00:00,  8.61it/s, v_num=0, train/rmse=1.06e+3, train/mape=1.690, val/rmse=446.0, val/mape=0.220]Epoch 214, global step 9890: 'val/rmse' was not in top 1
# Epoch 215: 100% 46/46 [00:03<00:00, 12.92it/s, v_num=0, train/rmse=1.07e+3, train/mape=4.240, val/rmse=446.0, val/mape=0.220]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.10it/s]
# Epoch 215: 100% 46/46 [00:04<00:00, 11.12it/s, v_num=0, train/rmse=1.07e+3, train/mape=4.240, val/rmse=242.0, val/mape=0.134]Epoch 215, global step 9936: 'val/rmse' reached 242.23135 (best 242.23135), saving model to 'logs/CMamba/version_0/checkpoints/epoch215-val-rmse242.2314.ckpt' as top 1
# Epoch 216: 100% 46/46 [00:03<00:00, 12.80it/s, v_num=0, train/rmse=1.38e+3, train/mape=2.620, val/rmse=242.0, val/mape=0.134]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 24.65it/s]
# Epoch 216: 100% 46/46 [00:04<00:00, 10.82it/s, v_num=0, train/rmse=1.38e+3, train/mape=2.620, val/rmse=505.0, val/mape=0.266]Epoch 216, global step 9982: 'val/rmse' was not in top 1
# Epoch 217: 100% 46/46 [00:04<00:00,  9.85it/s, v_num=0, train/rmse=1.55e+3, train/mape=2.930, val/rmse=505.0, val/mape=0.266]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.76it/s]
# Epoch 217: 100% 46/46 [00:05<00:00,  8.81it/s, v_num=0, train/rmse=1.55e+3, train/mape=2.930, val/rmse=236.0, val/mape=0.133]Epoch 217, global step 10028: 'val/rmse' reached 235.66557 (best 235.66557), saving model to 'logs/CMamba/version_0/checkpoints/epoch217-val-rmse235.6656.ckpt' as top 1
# Epoch 218: 100% 46/46 [00:03<00:00, 12.92it/s, v_num=0, train/rmse=1.81e+3, train/mape=2.830, val/rmse=236.0, val/mape=0.133]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.85it/s]
# Epoch 218: 100% 46/46 [00:04<00:00, 11.15it/s, v_num=0, train/rmse=1.81e+3, train/mape=2.830, val/rmse=292.0, val/mape=0.154]Epoch 218, global step 10074: 'val/rmse' was not in top 1
# Epoch 219: 100% 46/46 [00:03<00:00, 12.60it/s, v_num=0, train/rmse=1.38e+3, train/mape=0.643, val/rmse=292.0, val/mape=0.154]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 21.18it/s]
# Epoch 219: 100% 46/46 [00:04<00:00, 10.35it/s, v_num=0, train/rmse=1.38e+3, train/mape=0.643, val/rmse=831.0, val/mape=0.481]Epoch 219, global step 10120: 'val/rmse' was not in top 1
# Epoch 220: 100% 46/46 [00:04<00:00,  9.60it/s, v_num=0, train/rmse=1.46e+3, train/mape=5.270, val/rmse=831.0, val/mape=0.481]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.16it/s]
# Epoch 220: 100% 46/46 [00:05<00:00,  8.58it/s, v_num=0, train/rmse=1.46e+3, train/mape=5.270, val/rmse=566.0, val/mape=0.351]Epoch 220, global step 10166: 'val/rmse' was not in top 1
# Epoch 221: 100% 46/46 [00:04<00:00, 11.34it/s, v_num=0, train/rmse=1.8e+3, train/mape=3.550, val/rmse=566.0, val/mape=0.351]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.89it/s]
# Epoch 221: 100% 46/46 [00:04<00:00,  9.99it/s, v_num=0, train/rmse=1.8e+3, train/mape=3.550, val/rmse=250.0, val/mape=0.141]Epoch 221, global step 10212: 'val/rmse' was not in top 1
# Epoch 222: 100% 46/46 [00:04<00:00,  9.85it/s, v_num=0, train/rmse=1.55e+3, train/mape=0.393, val/rmse=250.0, val/mape=0.141]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 21.73it/s]
# Epoch 222: 100% 46/46 [00:05<00:00,  8.34it/s, v_num=0, train/rmse=1.55e+3, train/mape=0.393, val/rmse=712.0, val/mape=0.451]Epoch 222, global step 10258: 'val/rmse' was not in top 1
# Epoch 223: 100% 46/46 [00:04<00:00, 10.31it/s, v_num=0, train/rmse=1.3e+3, train/mape=4.020, val/rmse=712.0, val/mape=0.451]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.69it/s]
# Epoch 223: 100% 46/46 [00:05<00:00,  9.16it/s, v_num=0, train/rmse=1.3e+3, train/mape=4.020, val/rmse=386.0, val/mape=0.223]Epoch 223, global step 10304: 'val/rmse' was not in top 1
# Epoch 224: 100% 46/46 [00:04<00:00, 10.46it/s, v_num=0, train/rmse=1.77e+3, train/mape=1.640, val/rmse=386.0, val/mape=0.223]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.34it/s]
# Epoch 224: 100% 46/46 [00:04<00:00,  9.29it/s, v_num=0, train/rmse=1.77e+3, train/mape=1.640, val/rmse=566.0, val/mape=0.303]Epoch 224, global step 10350: 'val/rmse' was not in top 1
# Epoch 225: 100% 46/46 [00:04<00:00,  9.58it/s, v_num=0, train/rmse=1.27e+3, train/mape=6.900, val/rmse=566.0, val/mape=0.303]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 33.18it/s]
# Epoch 225: 100% 46/46 [00:05<00:00,  8.58it/s, v_num=0, train/rmse=1.27e+3, train/mape=6.900, val/rmse=1.32e+3, val/mape=0.796]Epoch 225, global step 10396: 'val/rmse' was not in top 1
# Epoch 226: 100% 46/46 [00:03<00:00, 12.89it/s, v_num=0, train/rmse=1.2e+3, train/mape=2.230, val/rmse=1.32e+3, val/mape=0.796]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.76it/s]
# Epoch 226: 100% 46/46 [00:04<00:00, 11.17it/s, v_num=0, train/rmse=1.2e+3, train/mape=2.230, val/rmse=366.0, val/mape=0.210]Epoch 226, global step 10442: 'val/rmse' was not in top 1
# Epoch 227: 100% 46/46 [00:03<00:00, 12.74it/s, v_num=0, train/rmse=1.39e+3, train/mape=1.960, val/rmse=366.0, val/mape=0.210]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 25.43it/s]
# Epoch 227: 100% 46/46 [00:04<00:00, 10.81it/s, v_num=0, train/rmse=1.39e+3, train/mape=1.960, val/rmse=405.0, val/mape=0.197]Epoch 227, global step 10488: 'val/rmse' was not in top 1
# Epoch 228: 100% 46/46 [00:04<00:00, 10.08it/s, v_num=0, train/rmse=383.0, train/mape=0.361, val/rmse=405.0, val/mape=0.197]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.81it/s]
# Epoch 228: 100% 46/46 [00:05<00:00,  9.00it/s, v_num=0, train/rmse=383.0, train/mape=0.361, val/rmse=1.85e+3, val/mape=1.140]Epoch 228, global step 10534: 'val/rmse' was not in top 1
# Epoch 229: 100% 46/46 [00:03<00:00, 12.48it/s, v_num=0, train/rmse=1.26e+3, train/mape=2.020, val/rmse=1.85e+3, val/mape=1.140]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 33.29it/s]
# Epoch 229: 100% 46/46 [00:04<00:00, 10.85it/s, v_num=0, train/rmse=1.26e+3, train/mape=2.020, val/rmse=234.0, val/mape=0.132]Epoch 229, global step 10580: 'val/rmse' reached 233.67451 (best 233.67451), saving model to 'logs/CMamba/version_0/checkpoints/epoch229-val-rmse233.6745.ckpt' as top 1
# Epoch 230: 100% 46/46 [00:03<00:00, 12.58it/s, v_num=0, train/rmse=1.35e+3, train/mape=0.986, val/rmse=234.0, val/mape=0.132]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 21.48it/s]
# Epoch 230: 100% 46/46 [00:04<00:00, 10.18it/s, v_num=0, train/rmse=1.35e+3, train/mape=0.986, val/rmse=598.0, val/mape=0.328]Epoch 230, global step 10626: 'val/rmse' was not in top 1
# Epoch 231: 100% 46/46 [00:04<00:00, 10.52it/s, v_num=0, train/rmse=1.32e+3, train/mape=3.920, val/rmse=598.0, val/mape=0.328]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.84it/s]
# Epoch 231: 100% 46/46 [00:04<00:00,  9.33it/s, v_num=0, train/rmse=1.32e+3, train/mape=3.920, val/rmse=299.0, val/mape=0.163]Epoch 231, global step 10672: 'val/rmse' was not in top 1
# Epoch 232: 100% 46/46 [00:03<00:00, 12.80it/s, v_num=0, train/rmse=976.0, train/mape=6.260, val/rmse=299.0, val/mape=0.163]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 34.29it/s]
# Epoch 232: 100% 46/46 [00:04<00:00, 11.12it/s, v_num=0, train/rmse=976.0, train/mape=6.260, val/rmse=1.44e+3, val/mape=0.874]Epoch 232, global step 10718: 'val/rmse' was not in top 1
# Epoch 233: 100% 46/46 [00:03<00:00, 12.00it/s, v_num=0, train/rmse=1.38e+3, train/mape=0.735, val/rmse=1.44e+3, val/mape=0.874]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 21.43it/s]
# Epoch 233: 100% 46/46 [00:04<00:00,  9.83it/s, v_num=0, train/rmse=1.38e+3, train/mape=0.735, val/rmse=827.0, val/mape=0.473]Epoch 233, global step 10764: 'val/rmse' was not in top 1
# Epoch 234: 100% 46/46 [00:04<00:00, 10.96it/s, v_num=0, train/rmse=1.55e+3, train/mape=2.860, val/rmse=827.0, val/mape=0.473]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.30it/s]
# Epoch 234: 100% 46/46 [00:04<00:00,  9.67it/s, v_num=0, train/rmse=1.55e+3, train/mape=2.860, val/rmse=342.0, val/mape=0.172]Epoch 234, global step 10810: 'val/rmse' was not in top 1
# Epoch 235: 100% 46/46 [00:03<00:00, 12.97it/s, v_num=0, train/rmse=1e+3, train/mape=1.520, val/rmse=342.0, val/mape=0.172]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.63it/s]
# Epoch 235: 100% 46/46 [00:04<00:00, 11.20it/s, v_num=0, train/rmse=1e+3, train/mape=1.520, val/rmse=303.0, val/mape=0.158]Epoch 235, global step 10856: 'val/rmse' was not in top 1
# Epoch 236: 100% 46/46 [00:04<00:00, 10.73it/s, v_num=0, train/rmse=1.84e+3, train/mape=2.160, val/rmse=303.0, val/mape=0.158]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 18.71it/s]
# Epoch 236: 100% 46/46 [00:05<00:00,  8.79it/s, v_num=0, train/rmse=1.84e+3, train/mape=2.160, val/rmse=225.0, val/mape=0.127]Epoch 236, global step 10902: 'val/rmse' reached 224.61327 (best 224.61327), saving model to 'logs/CMamba/version_0/checkpoints/epoch236-val-rmse224.6133.ckpt' as top 1
# Epoch 237: 100% 46/46 [00:03<00:00, 12.18it/s, v_num=0, train/rmse=1.49e+3, train/mape=0.464, val/rmse=225.0, val/mape=0.127]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.36it/s]
# Epoch 237: 100% 46/46 [00:04<00:00, 10.56it/s, v_num=0, train/rmse=1.49e+3, train/mape=0.464, val/rmse=250.0, val/mape=0.142]Epoch 237, global step 10948: 'val/rmse' was not in top 1
# Epoch 238: 100% 46/46 [00:03<00:00, 12.67it/s, v_num=0, train/rmse=831.0, train/mape=2.390, val/rmse=250.0, val/mape=0.142]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.04it/s]
# Epoch 238: 100% 46/46 [00:04<00:00, 10.92it/s, v_num=0, train/rmse=831.0, train/mape=2.390, val/rmse=539.0, val/mape=0.283]Epoch 238, global step 10994: 'val/rmse' was not in top 1
# Epoch 239: 100% 46/46 [00:04<00:00, 10.06it/s, v_num=0, train/rmse=1.22e+3, train/mape=3.880, val/rmse=539.0, val/mape=0.283]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 22.29it/s]
# Epoch 239: 100% 46/46 [00:05<00:00,  8.50it/s, v_num=0, train/rmse=1.22e+3, train/mape=3.880, val/rmse=232.0, val/mape=0.131]Epoch 239, global step 11040: 'val/rmse' was not in top 1
# Epoch 240: 100% 46/46 [00:03<00:00, 12.67it/s, v_num=0, train/rmse=991.0, train/mape=5.490, val/rmse=232.0, val/mape=0.131]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.42it/s]
# Epoch 240: 100% 46/46 [00:04<00:00, 11.00it/s, v_num=0, train/rmse=991.0, train/mape=5.490, val/rmse=624.0, val/mape=0.345]Epoch 240, global step 11086: 'val/rmse' was not in top 1
# Epoch 241: 100% 46/46 [00:03<00:00, 12.60it/s, v_num=0, train/rmse=819.0, train/mape=4.100, val/rmse=624.0, val/mape=0.345]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.66it/s]
# Epoch 241: 100% 46/46 [00:04<00:00, 10.89it/s, v_num=0, train/rmse=819.0, train/mape=4.100, val/rmse=1.04e+3, val/mape=0.617]Epoch 241, global step 11132: 'val/rmse' was not in top 1
# Epoch 242: 100% 46/46 [00:04<00:00,  9.55it/s, v_num=0, train/rmse=897.0, train/mape=2.030, val/rmse=1.04e+3, val/mape=0.617]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.10it/s]
# Epoch 242: 100% 46/46 [00:05<00:00,  8.43it/s, v_num=0, train/rmse=897.0, train/mape=2.030, val/rmse=394.0, val/mape=0.192]Epoch 242, global step 11178: 'val/rmse' was not in top 1
# Epoch 243: 100% 46/46 [00:03<00:00, 12.83it/s, v_num=0, train/rmse=1.55e+3, train/mape=5.770, val/rmse=394.0, val/mape=0.192]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 29.13it/s]
# Epoch 243: 100% 46/46 [00:04<00:00, 11.06it/s, v_num=0, train/rmse=1.55e+3, train/mape=5.770, val/rmse=333.0, val/mape=0.166]Epoch 243, global step 11224: 'val/rmse' was not in top 1
# Epoch 244: 100% 46/46 [00:03<00:00, 12.49it/s, v_num=0, train/rmse=1.06e+3, train/mape=4.010, val/rmse=333.0, val/mape=0.166]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 29.27it/s]
# Epoch 244: 100% 46/46 [00:04<00:00, 10.75it/s, v_num=0, train/rmse=1.06e+3, train/mape=4.010, val/rmse=283.0, val/mape=0.150]Epoch 244, global step 11270: 'val/rmse' was not in top 1
# Epoch 245: 100% 46/46 [00:04<00:00,  9.67it/s, v_num=0, train/rmse=759.0, train/mape=2.900, val/rmse=283.0, val/mape=0.150]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 28.16it/s]
# Epoch 245: 100% 46/46 [00:05<00:00,  8.60it/s, v_num=0, train/rmse=759.0, train/mape=2.900, val/rmse=770.0, val/mape=0.437]Epoch 245, global step 11316: 'val/rmse' was not in top 1
# Epoch 246: 100% 46/46 [00:03<00:00, 12.81it/s, v_num=0, train/rmse=1.31e+3, train/mape=4.590, val/rmse=770.0, val/mape=0.437]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.02it/s]
# Epoch 246: 100% 46/46 [00:04<00:00, 11.00it/s, v_num=0, train/rmse=1.31e+3, train/mape=4.590, val/rmse=368.0, val/mape=0.182]Epoch 246, global step 11362: 'val/rmse' was not in top 1
# Epoch 247: 100% 46/46 [00:03<00:00, 12.50it/s, v_num=0, train/rmse=867.0, train/mape=3.020, val/rmse=368.0, val/mape=0.182]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.70it/s]
# Epoch 247: 100% 46/46 [00:04<00:00, 10.78it/s, v_num=0, train/rmse=867.0, train/mape=3.020, val/rmse=523.0, val/mape=0.266]Epoch 247, global step 11408: 'val/rmse' was not in top 1
# Epoch 248: 100% 46/46 [00:04<00:00,  9.48it/s, v_num=0, train/rmse=1.02e+3, train/mape=4.460, val/rmse=523.0, val/mape=0.266]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.92it/s]
# Epoch 248: 100% 46/46 [00:05<00:00,  8.49it/s, v_num=0, train/rmse=1.02e+3, train/mape=4.460, val/rmse=623.0, val/mape=0.336]Epoch 248, global step 11454: 'val/rmse' was not in top 1
# Epoch 249: 100% 46/46 [00:03<00:00, 12.33it/s, v_num=0, train/rmse=1.53e+3, train/mape=2.810, val/rmse=623.0, val/mape=0.336]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.15it/s]
# Epoch 249: 100% 46/46 [00:04<00:00, 10.71it/s, v_num=0, train/rmse=1.53e+3, train/mape=2.810, val/rmse=646.0, val/mape=0.351]Epoch 249, global step 11500: 'val/rmse' was not in top 1
# Epoch 250: 100% 46/46 [00:03<00:00, 12.57it/s, v_num=0, train/rmse=862.0, train/mape=2.570, val/rmse=646.0, val/mape=0.351]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 23.97it/s]
# Epoch 250: 100% 46/46 [00:04<00:00, 10.35it/s, v_num=0, train/rmse=862.0, train/mape=2.570, val/rmse=878.0, val/mape=0.506]Epoch 250, global step 11546: 'val/rmse' was not in top 1
# Epoch 251: 100% 46/46 [00:04<00:00, 10.21it/s, v_num=0, train/rmse=1.48e+3, train/mape=3.910, val/rmse=878.0, val/mape=0.506]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 29.18it/s]
# Epoch 251: 100% 46/46 [00:05<00:00,  9.06it/s, v_num=0, train/rmse=1.48e+3, train/mape=3.910, val/rmse=638.0, val/mape=0.346]Epoch 251, global step 11592: 'val/rmse' was not in top 1
# Epoch 252: 100% 46/46 [00:03<00:00, 12.73it/s, v_num=0, train/rmse=1.28e+3, train/mape=6.060, val/rmse=638.0, val/mape=0.346]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 28.59it/s]
# Epoch 252: 100% 46/46 [00:04<00:00, 10.95it/s, v_num=0, train/rmse=1.28e+3, train/mape=6.060, val/rmse=386.0, val/mape=0.190]Epoch 252, global step 11638: 'val/rmse' was not in top 1
# Epoch 253: 100% 46/46 [00:03<00:00, 11.86it/s, v_num=0, train/rmse=1.32e+3, train/mape=4.210, val/rmse=386.0, val/mape=0.190]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 19.71it/s]
# Epoch 253: 100% 46/46 [00:04<00:00,  9.69it/s, v_num=0, train/rmse=1.32e+3, train/mape=4.210, val/rmse=452.0, val/mape=0.220]Epoch 253, global step 11684: 'val/rmse' was not in top 1
# Epoch 254: 100% 46/46 [00:04<00:00, 11.05it/s, v_num=0, train/rmse=1.81e+3, train/mape=1.200, val/rmse=452.0, val/mape=0.220]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.21it/s]
# Epoch 254: 100% 46/46 [00:04<00:00,  9.69it/s, v_num=0, train/rmse=1.81e+3, train/mape=1.200, val/rmse=488.0, val/mape=0.243]Epoch 254, global step 11730: 'val/rmse' was not in top 1
# Epoch 255: 100% 46/46 [00:03<00:00, 12.73it/s, v_num=0, train/rmse=814.0, train/mape=3.790, val/rmse=488.0, val/mape=0.243]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 26.54it/s]
# Epoch 255: 100% 46/46 [00:04<00:00, 10.86it/s, v_num=0, train/rmse=814.0, train/mape=3.790, val/rmse=757.0, val/mape=0.426]Epoch 255, global step 11776: 'val/rmse' was not in top 1
# Epoch 256: 100% 46/46 [00:04<00:00, 11.06it/s, v_num=0, train/rmse=875.0, train/mape=4.380, val/rmse=757.0, val/mape=0.426]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 19.39it/s]
# Epoch 256: 100% 46/46 [00:05<00:00,  9.03it/s, v_num=0, train/rmse=875.0, train/mape=4.380, val/rmse=638.0, val/mape=0.344]Epoch 256, global step 11822: 'val/rmse' was not in top 1
# Epoch 257: 100% 46/46 [00:03<00:00, 12.09it/s, v_num=0, train/rmse=970.0, train/mape=2.840, val/rmse=638.0, val/mape=0.344]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.88it/s]
# Epoch 257: 100% 46/46 [00:04<00:00, 10.49it/s, v_num=0, train/rmse=970.0, train/mape=2.840, val/rmse=431.0, val/mape=0.210]Epoch 257, global step 11868: 'val/rmse' was not in top 1
# Epoch 258: 100% 46/46 [00:03<00:00, 12.72it/s, v_num=0, train/rmse=1.38e+3, train/mape=2.360, val/rmse=431.0, val/mape=0.210]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.37it/s]
# Epoch 258: 100% 46/46 [00:04<00:00, 11.03it/s, v_num=0, train/rmse=1.38e+3, train/mape=2.360, val/rmse=391.0, val/mape=0.193]Epoch 258, global step 11914: 'val/rmse' was not in top 1
# Epoch 259: 100% 46/46 [00:04<00:00, 10.48it/s, v_num=0, train/rmse=1.09e+3, train/mape=2.730, val/rmse=391.0, val/mape=0.193]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 20.78it/s]
# Epoch 259: 100% 46/46 [00:05<00:00,  8.70it/s, v_num=0, train/rmse=1.09e+3, train/mape=2.730, val/rmse=731.0, val/mape=0.408]Epoch 259, global step 11960: 'val/rmse' was not in top 1
# Epoch 260: 100% 46/46 [00:03<00:00, 12.34it/s, v_num=0, train/rmse=1.91e+3, train/mape=0.975, val/rmse=731.0, val/mape=0.408]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.88it/s]
# Epoch 260: 100% 46/46 [00:04<00:00, 10.71it/s, v_num=0, train/rmse=1.91e+3, train/mape=0.975, val/rmse=278.0, val/mape=0.153]Epoch 260, global step 12006: 'val/rmse' was not in top 1
# Epoch 261: 100% 46/46 [00:03<00:00, 12.46it/s, v_num=0, train/rmse=1.15e+3, train/mape=2.190, val/rmse=278.0, val/mape=0.153]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.02it/s]
# ...
# Epoch 971: 100% 46/46 [00:03<00:00, 12.40it/s, v_num=0, train/rmse=179.0, train/mape=0.441, val/rmse=50.50, val/mape=0.0237]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 23.36it/s]
# Epoch 971: 100% 46/46 [00:04<00:00, 10.44it/s, v_num=0, train/rmse=179.0, train/mape=0.441, val/rmse=135.0, val/mape=0.0807]Epoch 971, global step 44712: 'val/rmse' was not in top 1
# Epoch 972: 100% 46/46 [00:04<00:00,  9.78it/s, v_num=0, train/rmse=103.0, train/mape=0.0491, val/rmse=135.0, val/mape=0.0807]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 27.85it/s]
# Epoch 972: 100% 46/46 [00:05<00:00,  8.63it/s, v_num=0, train/rmse=103.0, train/mape=0.0491, val/rmse=94.10, val/mape=0.0541]Epoch 972, global step 44758: 'val/rmse' was not in top 1
# Epoch 973: 100% 46/46 [00:03<00:00, 12.15it/s, v_num=0, train/rmse=377.0, train/mape=0.163, val/rmse=94.10, val/mape=0.0541]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 29.52it/s]
# Epoch 973: 100% 46/46 [00:04<00:00, 10.42it/s, v_num=0, train/rmse=377.0, train/mape=0.163, val/rmse=97.70, val/mape=0.0557]Epoch 973, global step 44804: 'val/rmse' was not in top 1
# Epoch 974: 100% 46/46 [00:03<00:00, 11.65it/s, v_num=0, train/rmse=77.80, train/mape=0.211, val/rmse=97.70, val/mape=0.0557]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 20.19it/s]
# Epoch 974: 100% 46/46 [00:04<00:00,  9.43it/s, v_num=0, train/rmse=77.80, train/mape=0.211, val/rmse=119.0, val/mape=0.0698]Epoch 974, global step 44850: 'val/rmse' was not in top 1
# Epoch 975: 100% 46/46 [00:04<00:00, 10.61it/s, v_num=0, train/rmse=78.90, train/mape=0.283, val/rmse=119.0, val/mape=0.0698]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 28.64it/s]
# Epoch 975: 100% 46/46 [00:04<00:00,  9.30it/s, v_num=0, train/rmse=78.90, train/mape=0.283, val/rmse=89.30, val/mape=0.0508]Epoch 975, global step 44896: 'val/rmse' was not in top 1
# Epoch 976: 100% 46/46 [00:03<00:00, 12.12it/s, v_num=0, train/rmse=59.80, train/mape=0.177, val/rmse=89.30, val/mape=0.0508]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 27.17it/s]
# Epoch 976: 100% 46/46 [00:04<00:00, 10.42it/s, v_num=0, train/rmse=59.80, train/mape=0.177, val/rmse=81.10, val/mape=0.0444]Epoch 976, global step 44942: 'val/rmse' was not in top 1
# Epoch 977: 100% 46/46 [00:04<00:00, 10.44it/s, v_num=0, train/rmse=69.40, train/mape=0.0821, val/rmse=81.10, val/mape=0.0444]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 19.92it/s]
# Epoch 977: 100% 46/46 [00:05<00:00,  8.59it/s, v_num=0, train/rmse=69.40, train/mape=0.0821, val/rmse=59.80, val/mape=0.0306]Epoch 977, global step 44988: 'val/rmse' was not in top 1
# Epoch 978: 100% 46/46 [00:03<00:00, 12.29it/s, v_num=0, train/rmse=101.0, train/mape=0.044, val/rmse=59.80, val/mape=0.0306]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 29.07it/s]
# Epoch 978: 100% 46/46 [00:04<00:00, 10.58it/s, v_num=0, train/rmse=101.0, train/mape=0.044, val/rmse=96.50, val/mape=0.0547]Epoch 978, global step 45034: 'val/rmse' was not in top 1
# Epoch 979: 100% 46/46 [00:03<00:00, 12.44it/s, v_num=0, train/rmse=132.0, train/mape=0.284, val/rmse=96.50, val/mape=0.0547]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 28.04it/s]
# Epoch 979: 100% 46/46 [00:04<00:00, 10.69it/s, v_num=0, train/rmse=132.0, train/mape=0.284, val/rmse=123.0, val/mape=0.072]Epoch 979, global step 45080: 'val/rmse' was not in top 1
# Epoch 980: 100% 46/46 [00:04<00:00,  9.52it/s, v_num=0, train/rmse=16.50, train/mape=0.0489, val/rmse=123.0, val/mape=0.072]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 32.63it/s]
# Epoch 980: 100% 46/46 [00:05<00:00,  8.51it/s, v_num=0, train/rmse=16.50, train/mape=0.0489, val/rmse=48.70, val/mape=0.0226]Epoch 980, global step 45126: 'val/rmse' was not in top 1
# Epoch 981: 100% 46/46 [00:03<00:00, 12.50it/s, v_num=0, train/rmse=62.10, train/mape=0.136, val/rmse=48.70, val/mape=0.0226]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 29.18it/s]
# Epoch 981: 100% 46/46 [00:04<00:00, 10.77it/s, v_num=0, train/rmse=62.10, train/mape=0.136, val/rmse=104.0, val/mape=0.0601]Epoch 981, global step 45172: 'val/rmse' was not in top 1
# Epoch 982: 100% 46/46 [00:03<00:00, 12.14it/s, v_num=0, train/rmse=56.40, train/mape=0.123, val/rmse=104.0, val/mape=0.0601]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 29.33it/s]
# Epoch 982: 100% 46/46 [00:04<00:00, 10.50it/s, v_num=0, train/rmse=56.40, train/mape=0.123, val/rmse=49.00, val/mape=0.0219]Epoch 982, global step 45218: 'val/rmse' was not in top 1
# Epoch 983: 100% 46/46 [00:04<00:00,  9.64it/s, v_num=0, train/rmse=68.90, train/mape=0.125, val/rmse=49.00, val/mape=0.0219]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 28.10it/s]
# Epoch 983: 100% 46/46 [00:05<00:00,  8.53it/s, v_num=0, train/rmse=68.90, train/mape=0.125, val/rmse=106.0, val/mape=0.061]Epoch 983, global step 45264: 'val/rmse' was not in top 1
# Epoch 984: 100% 46/46 [00:03<00:00, 12.39it/s, v_num=0, train/rmse=91.90, train/mape=0.380, val/rmse=106.0, val/mape=0.061]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.75it/s]
# Epoch 984: 100% 46/46 [00:04<00:00, 10.68it/s, v_num=0, train/rmse=91.90, train/mape=0.380, val/rmse=50.20, val/mape=0.0226]Epoch 984, global step 45310: 'val/rmse' was not in top 1
# Epoch 985: 100% 46/46 [00:03<00:00, 12.15it/s, v_num=0, train/rmse=114.0, train/mape=0.0592, val/rmse=50.20, val/mape=0.0226]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 20.70it/s]
# Epoch 985: 100% 46/46 [00:04<00:00, 10.14it/s, v_num=0, train/rmse=114.0, train/mape=0.0592, val/rmse=135.0, val/mape=0.0805]Epoch 985, global step 45356: 'val/rmse' was not in top 1
# Epoch 986: 100% 46/46 [00:04<00:00,  9.96it/s, v_num=0, train/rmse=99.90, train/mape=0.0537, val/rmse=135.0, val/mape=0.0805]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 28.39it/s]
# Epoch 986: 100% 46/46 [00:05<00:00,  8.82it/s, v_num=0, train/rmse=99.90, train/mape=0.0537, val/rmse=85.00, val/mape=0.0477]Epoch 986, global step 45402: 'val/rmse' was not in top 1
# Epoch 987: 100% 46/46 [00:03<00:00, 12.19it/s, v_num=0, train/rmse=213.0, train/mape=0.194, val/rmse=85.00, val/mape=0.0477]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 29.70it/s]
# Epoch 987: 100% 46/46 [00:04<00:00, 10.56it/s, v_num=0, train/rmse=213.0, train/mape=0.194, val/rmse=196.0, val/mape=0.120]Epoch 987, global step 45448: 'val/rmse' was not in top 1
# Epoch 988: 100% 46/46 [00:03<00:00, 11.70it/s, v_num=0, train/rmse=98.40, train/mape=0.0487, val/rmse=196.0, val/mape=0.120]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 20.67it/s]
# Epoch 988: 100% 46/46 [00:04<00:00,  9.48it/s, v_num=0, train/rmse=98.40, train/mape=0.0487, val/rmse=137.0, val/mape=0.0817]Epoch 988, global step 45494: 'val/rmse' was not in top 1
# Epoch 989: 100% 46/46 [00:04<00:00, 10.67it/s, v_num=0, train/rmse=123.0, train/mape=0.230, val/rmse=137.0, val/mape=0.0817]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.32it/s]
# Epoch 989: 100% 46/46 [00:04<00:00,  9.35it/s, v_num=0, train/rmse=123.0, train/mape=0.230, val/rmse=52.90, val/mape=0.0253]Epoch 989, global step 45540: 'val/rmse' was not in top 1
# Epoch 990: 100% 46/46 [00:03<00:00, 12.49it/s, v_num=0, train/rmse=136.0, train/mape=0.0488, val/rmse=52.90, val/mape=0.0253]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.36it/s]
# Epoch 990: 100% 46/46 [00:04<00:00, 10.78it/s, v_num=0, train/rmse=136.0, train/mape=0.0488, val/rmse=71.90, val/mape=0.0378]Epoch 990, global step 45586: 'val/rmse' was not in top 1
# Epoch 991: 100% 46/46 [00:04<00:00, 10.85it/s, v_num=0, train/rmse=202.0, train/mape=0.0967, val/rmse=71.90, val/mape=0.0378]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 18.87it/s]
# Epoch 991: 100% 46/46 [00:05<00:00,  8.93it/s, v_num=0, train/rmse=202.0, train/mape=0.0967, val/rmse=149.0, val/mape=0.0896]Epoch 991, global step 45632: 'val/rmse' was not in top 1
# Epoch 992: 100% 46/46 [00:03<00:00, 11.67it/s, v_num=0, train/rmse=49.40, train/mape=0.0496, val/rmse=149.0, val/mape=0.0896]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.29it/s]
# Epoch 992: 100% 46/46 [00:04<00:00, 10.14it/s, v_num=0, train/rmse=49.40, train/mape=0.0496, val/rmse=50.70, val/mape=0.0236]Epoch 992, global step 45678: 'val/rmse' was not in top 1
# Epoch 993: 100% 46/46 [00:03<00:00, 12.38it/s, v_num=0, train/rmse=29.20, train/mape=0.0306, val/rmse=50.70, val/mape=0.0236]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 30.41it/s]
# Epoch 993: 100% 46/46 [00:04<00:00, 10.72it/s, v_num=0, train/rmse=29.20, train/mape=0.0306, val/rmse=74.50, val/mape=0.040]Epoch 993, global step 45724: 'val/rmse' was not in top 1
# Epoch 994: 100% 46/46 [00:04<00:00,  9.91it/s, v_num=0, train/rmse=173.0, train/mape=0.322, val/rmse=74.50, val/mape=0.040]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 28.67it/s]
# Epoch 994: 100% 46/46 [00:05<00:00,  8.50it/s, v_num=0, train/rmse=173.0, train/mape=0.322, val/rmse=141.0, val/mape=0.0846]Epoch 994, global step 45770: 'val/rmse' was not in top 1
# Epoch 995: 100% 46/46 [00:03<00:00, 12.24it/s, v_num=0, train/rmse=231.0, train/mape=0.204, val/rmse=141.0, val/mape=0.0846]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 28.17it/s]
# Epoch 995: 100% 46/46 [00:04<00:00, 10.52it/s, v_num=0, train/rmse=231.0, train/mape=0.204, val/rmse=95.70, val/mape=0.0543]Epoch 995, global step 45816: 'val/rmse' was not in top 1
# Epoch 996: 100% 46/46 [00:03<00:00, 12.08it/s, v_num=0, train/rmse=173.0, train/mape=0.610, val/rmse=95.70, val/mape=0.0543]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 29.38it/s]
# Epoch 996: 100% 46/46 [00:04<00:00, 10.46it/s, v_num=0, train/rmse=173.0, train/mape=0.610, val/rmse=78.00, val/mape=0.0434]Epoch 996, global step 45862: 'val/rmse' was not in top 1
# Epoch 997: 100% 46/46 [00:04<00:00,  9.42it/s, v_num=0, train/rmse=37.00, train/mape=0.133, val/rmse=78.00, val/mape=0.0434]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 31.58it/s]
# Epoch 997: 100% 46/46 [00:05<00:00,  8.43it/s, v_num=0, train/rmse=37.00, train/mape=0.133, val/rmse=152.0, val/mape=0.0915]Epoch 997, global step 45908: 'val/rmse' was not in top 1
# Epoch 998: 100% 46/46 [00:03<00:00, 12.17it/s, v_num=0, train/rmse=36.80, train/mape=0.0817, val/rmse=152.0, val/mape=0.0915]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 27.41it/s]
# Epoch 998: 100% 46/46 [00:04<00:00, 10.47it/s, v_num=0, train/rmse=36.80, train/mape=0.0817, val/rmse=54.60, val/mape=0.0265]Epoch 998, global step 45954: 'val/rmse' was not in top 1
# Epoch 999: 100% 46/46 [00:03<00:00, 12.05it/s, v_num=0, train/rmse=31.30, train/mape=0.0351, val/rmse=54.60, val/mape=0.0265]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/11 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 11/11 [00:00<00:00, 22.07it/s]
# Epoch 999: 100% 46/46 [00:04<00:00, 10.09it/s, v_num=0, train/rmse=31.30, train/mape=0.0351, val/rmse=193.0, val/mape=0.118]Epoch 999, global step 46000: 'val/rmse' was not in top 1
# `Trainer.fit` stopped: `max_epochs=1000` reached.
# Epoch 999: 100% 46/46 [00:04<00:00,  9.94it/s, v_num=0, train/rmse=31.30, train/mape=0.0351, val/rmse=193.0, val/mape=0.118]
# Restoring states from the checkpoint path at logs/CMamba/version_0/checkpoints/epoch876-val-rmse47.5558.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at logs/CMamba/version_0/checkpoints/epoch876-val-rmse47.5558.ckpt
# 350 data points loaded as test split.
# Testing DataLoader 0: 100% 11/11 [00:00<00:00, 21.75it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/mae          │     70.91667175292969     │
# │         test/mape         │   0.025280481204390526    │
# │         test/mse          │      10479.513671875      │
# │         test/rmse         │    100.87920379638672     │
# └───────────────────────────┴───────────────────────────┘

# %%
# @title Evaluation
# !python scripts/evaluation.py --config cmamba_v --ckpt_path ./logs/CMamba/version_0/checkpoints/epoch*.ckpt
# Out:
# Seed set to 23
# ['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume']
# ['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume']
# ['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume']
# 1446 data points loaded as train split.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 350 data points loaded as val split.
# 350 data points loaded as test split.
#  Split        MSE          RMSE     MAPE      MAE
#  Train     10643.546     103.168   0.14244   69.711
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
#   Val      2469.903       49.698   0.02121   33.298
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
#  Test      10481.983     102.382   0.02528   70.912
# Test Direction Accuracy: 47.56%
# Test Win Rate: 47.56%
# Test Average Trade Loss: -2.23%
# Test Maximum Trade Loss: -19.27%

# %%
# @title Save model
# !python utils/save_to_drive.py
# Out:
# Created model dir: /content/drive/MyDrive/training/20251019_1628
# Copied epoch876-val-rmse47.5558.ckpt to /content/drive/MyDrive/training/20251019_1628
# Copied hparams.yaml to /content/drive/MyDrive/training/20251019_1628
# Copied data/ to /content/drive/MyDrive/training/20251019_1628
# Copied configs/ to /content/drive/MyDrive/training/20251019_1628
# Copied results/ to /content/drive/MyDrive/training/20251019_1628
# Copy done.

# %%
# @title Check version
# !python utils/print_package_versions.py
# Out:
# ipython: Not installed
# jedi: Not installed
# google_colab: Not installed
# requests: 2.32.4
# datasets: 4.0.0
# fsspec: 2025.3.0
# opencv_python: Not installed
# numpy: 2.0.2
# opencv_contrib_python: Not installed
# tensorflow: Not installed
# gcsfs: 2025.3.0
# cupy_cuda12x: Not installed
# numba: 0.60.0
# opencv_python_headless: Not installed
