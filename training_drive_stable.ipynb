# %% [markdown]
# <a href="https://colab.research.google.com/github/kewingchang/CryptoMamba/blob/Training/training_drive_stable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title System requirements
# 1. Training using stable mamba_ssm and causal_conv1d
# 2. torch == 2.8.0+cu126(cxx11abiTRUE)
# 3. python 3.12.12
# 4. mamba_ssm-2.2.5, causal_conv1d-1.5.2
# 5. Colab environment: python 2025-10

# %%
# @title Cloning
# !git clone -b Training https://github.com/kewingchang/CryptoMamba
# %cd CryptoMamba/

# %%
# @title Mount google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# @title Installing requirements
# !pip uninstall tensorflow -y
# !pip uninstall tensorflow-decision-forests dopamine-rl -y
# !pip uninstall tf_keras tf-slim -y
# !pip uninstall tensorflow-datasets tensorflow-hub tensorflow-metadata tensorflow-probability tensorflow-text -y

# !pip install -q ninja

# 拷贝whl from drive
# !cp /content/drive/MyDrive/my_libs/T4_python3.12_torch2.8.0+cu126_cxx11abiTRUE/causal_conv1d-1.5.2-cp312-cp312-linux_x86_64.whl /tmp/
# !cp /content/drive/MyDrive/my_libs/T4_python3.12_torch2.8.0+cu126_cxx11abiTRUE/mamba_ssm-2.2.5-cp312-cp312-linux_x86_64.whl /tmp/
# 安装 wheel 文件
# !pip install /tmp/causal_conv1d-1.5.2-cp312-cp312-linux_x86_64.whl /tmp/mamba_ssm-2.2.5-cp312-cp312-linux_x86_64.whl -v --no-build-isolation

# using stable version
# !pip install causal-conv1d==1.5.2 -v --no-build-isolation
# !pip install mamba-ssm==2.2.5 -v --no-build-isolation
# install others
# !pip install -r requirements.txt

# %%
# @title Training
# !python scripts/training-earlystop.py --config cmamba_v --save_checkpoints > ./log.txt 2>&1

# %%
# @title Evaluation
# !python scripts/evaluation.py --config cmamba_v --ckpt_path ./logs/CMamba/version_0/checkpoints/epoch*.ckpt >> ./log.txt 2>&1

# %%
# @title Save model
# !python utils/save_to_drive.py

# %%
# @title Prediction
# !python scripts/one_day_pred.py --config cmamba_v --ckpt_path ./logs/CMamba/version_0/checkpoints/epoch*.ckpt --data_path ./data/ETH_Dataset_daily.csv --date 2024-7-3

# %%
# @title Extract from drive
# !python scripts/extract_mase.py --data_dir /content/drive/MyDrive/training/20251210
