# %% [markdown]
# <a href="https://colab.research.google.com/github/kewingchang/CryptoMamba/blob/LightGBM/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Cloning
# !git clone -b LightGBM https://github.com/kewingchang/CryptoMamba /content/LightGBM
# %cd /content/LightGBM/

# %%
# @title Installing requirements
# !pip install -r requirements.txt

# %%
# @title Training BTC - Long
# !python scripts/training_updown.py \
  --close_chg_col PF_Close_Chg \
  --data_config configs/data_config/btc_long_260212.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# @title Training BTC - Short
# !python scripts/training_updown.py \
  --close_chg_col PF_Close_Chg \
  --data_config configs/data_config/btc_short_260212.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# @title Training ETH - Long
# !python scripts/training_updown.py \
  --close_chg_col PF_Close_Chg \
  --data_config configs/data_config/eth_long_260212.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# @title Training ETH - Short
# !python scripts/training_updown.py \
  --close_chg_col PF_Close_Chg \
  --data_config configs/data_config/eth_short_260212.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# @title BTC prediction
# !python scripts/one_day_pred.py \
  --long_model checkpoints/btc_long_260212.txt \
  --long_threshold 0.50 \
  --short_model checkpoints/btc_short_260212.txt \
  --short_threshold 0.46 \
  --data_path data/BTC-USD.csv \
  --pred_path data/Pred-BTC-USD.csv \
  --date 2018-3-20

# %%
# @title ETH prediction
# !python scripts/one_day_pred.py \
  --long_model checkpoints/eth_long_260212.txt \
  --long_threshold 0.55 \
  --short_model checkpoints/eth_short_260212.txt \
  --short_threshold 0.49 \
  --data_path data/ETH-USD.csv \
  --pred_path data/Pred-ETH-USD.csv \
  --date 2018-3-25

# %%
# @title Set current date

start_date = '2025-10-1'
end_date = '2026-1-31'

print(f"Start date set to: {start_date}")
print(f"End date set to: {end_date}")

# %%
# @title BTC many prediction
# !python utils/run_many_pred.py \
  --long_model checkpoints/btc_long_260212.txt \
  --long_threshold 0.50 \
  --short_model checkpoints/btc_short_260212.txt \
  --short_threshold 0.46 \
  --data_path data/BTC-USD.csv \
  --pred_path data/Pred-BTC-USD.csv \
  --start_date {start_date} \
  --end_date {end_date}

# %%
# @title ETH many prediction
# !python utils/run_many_pred.py \
  --long_model checkpoints/eth_long_260212.txt \
  --long_threshold 0.55 \
  --short_model checkpoints/eth_short_260212.txt \
  --short_threshold 0.49 \
  --data_path data/ETH-USD.csv \
  --pred_path data/Pred-ETH-USD.csv \
  --start_date {start_date} \
  --end_date {end_date}

# %%
# @title -------------------------Select Features-------------------------------

# %%
# @title Select features stepwise updown
# !python scripts/select_features_stepwise_updown.py \
  --close_chg_col PF_Close_Chg \
  --step_size 1 \
  --min_features 1 \
  --data_config configs/data_config/model.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# @title Select features brute force updown
# !python scripts/select_features_brute_force_updown.py \
  --close_chg_col PF_Close_Chg \
  --min_features 1 \
  --data_config configs/data_config/model.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# @title Training with features selected
# !python scripts/training_updown.py \
  --close_chg_col PF_Close_Chg \
  --data_config configs/data_config/model_n61.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# @title ----------------------------分割线--------------------------------------

# %%
# @title Optuna structure
# !python scripts/tune_stepwise_updown.py \
  --group structure \
  --close_chg_col PF_Close_Chg \
  --n_trials 500 \
  --data_config configs/data_config/model_updown.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# !python scripts/training_updown.py \
  --close_chg_col PF_Close_Chg \
  --data_config configs/data_config/model_updown.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# @title Optuna regularization
# !python scripts/tune_stepwise_updown.py \
  --group regularization \
  --close_chg_col PF_Close_Chg \
  --n_trials 500 \
  --data_config configs/data_config/model_updown.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# !python scripts/training_updown.py \
  --close_chg_col PF_Close_Chg \
  --data_config configs/data_config/model_updown.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# @title Optuna sampling
# !python scripts/tune_stepwise_updown.py \
  --group sampling \
  --close_chg_col PF_Close_Chg \
  --n_trials 500 \
  --data_config configs/data_config/model_updown.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# !python scripts/training_updown.py \
  --close_chg_col PF_Close_Chg \
  --data_config configs/data_config/model_updown.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# @title Optuna weight
# !python scripts/tune_stepwise_updown.py \
  --group weight \
  --close_chg_col PF_Close_Chg \
  --n_trials 500 \
  --data_config configs/data_config/model_updown.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# !python scripts/training_updown.py \
  --close_chg_col PF_Close_Chg \
  --data_config configs/data_config/model_updown.yaml \
  --params_config configs/params_config/params_updown.yaml \
  --training_config configs/training_config/training_updown.yaml

# %%
# !mkdir /content/LightGBM/yamls

# %%
# %cd /content/LightGBM/yamls

# %%
# !python remove_a_feature.py --todel next_halving_pos_angle

# %%
# %cd /content/LightGBM/configs/data_config

# %%
# !python merge_features.py --model model.yaml --feature_dir /content/LightGBM/yamls

# %%
# %cd /content/LightGBM/

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp -r /content/LightGBM/configs/data_config /content/drive/MyDrive/others

# %%
# @title ----------------------Batch run----------------------------------------

# %%
# 语法：!unzip <zip文件路径> -d <解压目标路径>
# !unzip /content/LightGBM/configs/models.zip -d /content/LightGBM/configs/

# %%
# !PYTHONUNBUFFERED=1 python utils/batch_run.py --start 1 --end 460 > ./log.txt 2>&1
