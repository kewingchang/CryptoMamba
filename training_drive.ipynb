# %% [markdown]
# <a href="https://colab.research.google.com/github/kewingchang/CryptoMamba/blob/Training/training_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title System requirements
# 1. python 3.12.12
# 2. torch==2.8.0+cu126(cxx11abiTRUE)
# 3. mamba_ssm-2.2.6.post3, causal_conv1d-1.5.4(cxx11abiTRUE)

# %%
# @title Cloning
# !git clone -b Training https://github.com/kewingchang/CryptoMamba
# %cd CryptoMamba/

# %%
# @title Mount google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# @title Installing requirements
# !pip uninstall tensorflow -y
# !pip uninstall tensorflow-decision-forests dopamine-rl -y
# !pip uninstall tf_keras tf-slim -y
# !pip uninstall tensorflow-datasets tensorflow-hub tensorflow-metadata tensorflow-probability tensorflow-text -y

# !pip install -q ninja

# 下载并安装 mamba-ssm(from drive) 和 causal-conv1d 的 wheel 文件
# !cp /content/drive/MyDrive/my_libs/mamba_ssm_cu12torch2.8cxx11abiTRUE-cp312/mamba_ssm-2.2.6.post3-cp312-cp312-linux_x86_64.whl /tmp/
# !wget https://github.com/Dao-AILab/causal-conv1d/releases/download/v1.5.4/causal_conv1d-1.5.4+cu12torch2.8cxx11abiTRUE-cp312-cp312-linux_x86_64.whl  -O /tmp/causal_conv1d-1.5.4-cp312-cp312-linux_x86_64.whl
# 安装 wheel 文件
# !pip install /tmp/causal_conv1d-1.5.4-cp312-cp312-linux_x86_64.whl /tmp/mamba_ssm-2.2.6.post3-cp312-cp312-linux_x86_64.whl -v --no-build-isolation
# 安装其他包
# !pip install -r requirements.txt

# %%
# @title Training
# !python scripts/training-reproducibility.py --config cmamba_v --save_checkpoints

# %%
# @title Evaluation
# !python scripts/evaluation.py --config cmamba_v --ckpt_path ./logs/CMamba/version_0/checkpoints/epoch*.ckpt

# %%
# @title Save model
# !python utils/save_to_drive.py
